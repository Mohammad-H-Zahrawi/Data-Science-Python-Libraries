# %% [markdown]
# ## Imports and Set-up

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 4.8.2

# %%
import chart_studio.plotly as py

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
import cufflinks as cf

# %%
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df=pd.DataFrame(np.random.randn(50,4),columns='A B C D'.split())

# %%
df.head(2)
# Out:
#           A         B         C         D
# 0  2.993614 -1.221129 -0.561938 -1.880371
# 1 -0.671620 -0.398441 -3.174740 -1.081400

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# ## Scatter

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=20)
# Out:
# <div>
#
#
#             <div id="08dfa160-3d47-4377-b671-14d1810aac48" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("08dfa160-3d47-4377-b671-14d1810aac48")) {
#                     Plotly.newPlot(
#                         '08dfa160-3d47-4377-b671-14d1810aac48',
# ...

# %%
df.iplot(kind='scatter')
# Out:
# <div>
#
#
#             <div id="6a57a00f-4026-4d6a-9e41-3beb07324c72" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6a57a00f-4026-4d6a-9e41-3beb07324c72")) {
#                     Plotly.newPlot(
#                         '6a57a00f-4026-4d6a-9e41-3beb07324c72',
# ...

# %% [markdown]
# ## Bar Plots

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>
#
#
#             <div id="cf248dc4-d0a1-46fe-b6fc-162f3527a9e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cf248dc4-d0a1-46fe-b6fc-162f3527a9e8")) {
#                     Plotly.newPlot(
#                         'cf248dc4-d0a1-46fe-b6fc-162f3527a9e8',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.count().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="0ccfbb0e-e8f5-408d-abfc-2ed2d1c6218f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0ccfbb0e-e8f5-408d-abfc-2ed2d1c6218f")) {
#                     Plotly.newPlot(
#                         '0ccfbb0e-e8f5-408d-abfc-2ed2d1c6218f',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [50, 50, 50, 50]}],
# ...

# %% [markdown]
# ## box plots

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="d1d812ab-f22e-4b17-a9ab-36f3e9f90560" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d1d812ab-f22e-4b17-a9ab-36f3e9f90560")) {
#                     Plotly.newPlot(
#                         'd1d812ab-f22e-4b17-a9ab-36f3e9f90560',
# ...

# %% [markdown]
# ## 3d surface

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,10]})
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="55ffad83-97f4-4a03-bb0e-7dae4901a709" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("55ffad83-97f4-4a03-bb0e-7dae4901a709")) {
#                     Plotly.newPlot(
#                         '55ffad83-97f4-4a03-bb0e-7dae4901a709',
# ...

# %% [markdown]
# ## Spread

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="fe5eac44-ade3-42ab-aaaa-b346c2784047" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fe5eac44-ade3-42ab-aaaa-b346c2784047")) {
#                     Plotly.newPlot(
# ...

# %% [markdown]
# ## histogram

# %%
df['A'].iplot(kind='hist',bins=25)
# Out:
# <div>
#
#
#             <div id="153aed98-dbf2-4512-8b62-0f1c387338da" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("153aed98-dbf2-4512-8b62-0f1c387338da")) {
#                     Plotly.newPlot(
#                         '153aed98-dbf2-4512-8b62-0f1c387338da',
# ...

# %%
df.iplot(kind='hist',bins=50)
# Out:
# <div>
#
#
#             <div id="c0d36810-0956-4138-ae1b-f9d664f43ad6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c0d36810-0956-4138-ae1b-f9d664f43ad6")) {
#                     Plotly.newPlot(
#                         'c0d36810-0956-4138-ae1b-f9d664f43ad6',
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C',colors='Green')
# Out:
# <div>
#
#
#             <div id="f3586984-7cec-49c5-a465-6f8681bea233" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f3586984-7cec-49c5-a465-6f8681bea233")) {
#                     Plotly.newPlot(
#                         'f3586984-7cec-49c5-a465-6f8681bea233',
# ...

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="e6ff250e-019a-4f98-9b11-5fe693a71fa9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e6ff250e-019a-4f98-9b11-5fe693a71fa9")) {
#                     Plotly.newPlot(
#                         'e6ff250e-019a-4f98-9b11-5fe693a71fa9',
# ...

# %% [markdown]
# # Geographics MAps

# %% [markdown]
# ### Offline Plotly Usage

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import pandas as pd

# %%
data = dict(type = 'choropleth',
            locations = ['AZ','CA','NY'],
            locationmode = 'USA-states',
            colorscale= 'greens',
            text= ['text1','text2','text3'],
            z=[1.0,2.0,3.0],
            colorbar = {'title':'Colorbar Title'})

# %%
layout = dict(geo = {'scope':'usa'})

# %%
choromap = go.Figure(data = [data],layout = layout)

# %%
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="5bbfdc90-b9c3-4836-afe7-a784bc35333e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5bbfdc90-b9c3-4836-afe7-a784bc35333e")) {
#                     Plotly.newPlot(
#                         '5bbfdc90-b9c3-4836-afe7-a784bc35333e',
#                         [{"colorbar": {"title": {"text": "Colorbar Title"}}, "colorscale": [[0.0, "rgb(247,252,245)"], [0.125, "rgb(229,245,224)"], [0.25, "rgb(199,233,192)"], [0.375, "rgb(161,217,155)"], [0.5, "rgb(116,196,118)"], [0.625, "rgb(65,171,93)"], [0.75, "rgb(35,139,69)"], [0.875, "rgb(0,109,44)"], [1.0, "rgb(0,68,27)"]], "locationmode": "USA-states", "locations": ["AZ", "CA", "NY"], "text": ["text1", "text2", "text3"], "type": "choropleth", "z": [1.0, 2.0, 3.0]}],
# ...

# %%
df = pd.read_csv('2011_US_AGRI_Exports')
df.head(2)
# Out:
#   code    state category  total exports  beef  pork  poultry  dairy  \
# 0   AL  Alabama    state        1390.63  34.4  10.6    481.0   4.06
# 1   AK   Alaska    state          13.31   0.2   0.1      0.0   0.19
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
#
#    total veggies  corn  wheat  cotton  \
# 0          14.33  34.9   70.0  317.61
# 1           1.56   0.0    0.0    0.00
#
#                                                 text
# 0  Alabama<br>Beef 34.4 Dairy 4.06<br>Fruits 25.1...
# 1  Alaska<br>Beef 0.2 Dairy 0.19<br>Fruits 0.0 Ve...

# %%
data=dict(type='choropleth',colorscale='blues',locations=df['code'],z=df['total exports'],
          locationmode='USA-states',text=df['text'],marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"Millions USD"})

# %%
layout = dict(title = '2011 US Agriculture Exports by State',
              geo = dict(scope='usa',
                         showlakes = True,
                         lakecolor = 'rgb(85,173,240)')
             )

# %%
choromap = go.Figure(data = [data],layout = layout)

# %%
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="bb9267d2-e9a4-483d-8343-e2376ea82ba3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb9267d2-e9a4-483d-8343-e2376ea82ba3")) {
#                     Plotly.newPlot(
#                         'bb9267d2-e9a4-483d-8343-e2376ea82ba3',
# ...

# %% [markdown]
# # World Choropleth Map

# %%
df2 = pd.read_csv('2014_World_GDP')
df2.head()
# Out:
#           COUNTRY  GDP (BILLIONS) CODE
# 0     Afghanistan           21.71  AFG
# 1         Albania           13.40  ALB
# 2         Algeria          227.80  DZA
# 3  American Samoa            0.75  ASM
# 4         Andorra            4.80  AND

# %%
data = dict(
        type = 'choropleth',
        locations = df2['CODE'],
        z = df2['GDP (BILLIONS)'],
        text = df2['COUNTRY'],
        colorbar = {'title' : 'GDP Billions US'},
        colorscale='greens'
      )

# %%
layout = dict(
    title = '2014 Global GDP',
    geo = dict(
        showframe = False,
        projection = {'type':'orthographic'}
    )
)

# %%
choromap = go.Figure(data = [data],layout = layout)
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="51bd9e46-b08f-4961-91ac-7bbc04e6b132" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("51bd9e46-b08f-4961-91ac-7bbc04e6b132")) {
#                     Plotly.newPlot(
#                         '51bd9e46-b08f-4961-91ac-7bbc04e6b132',
# ...

# %% [markdown]
# # Build in Data Visuialization

# %%
df.head()
# Out:
#   code        state category  total exports   beef  pork  poultry   dairy  \
# 0   AL      Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK       Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ      Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR     Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA   California    state       16472.88  228.7  11.1    225.4  929.95
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# 4        2791.8       5944.6       8736.40          803.2        1303.5
#
#    total veggies  corn  wheat   cotton  \
# 0          14.33  34.9   70.0   317.61
# ...

# %%
df['poultry'].hist(bins=30)

# %%
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
df['beef'].hist(bins=10)

# %%
df[['beef','pork','cotton']].plot.area(alpha=0.4)

# %%
plt.rcParams['figure.figsize'] = [15, 10]
df.plot.bar(x='code',y='beef')

# %%
df.plot.bar(stacked=True)

# %%
plt.rcParams['figure.figsize'] = [8, 4]
df['total exports'].plot.hist()

# %%
df.plot.line(x='state',y='total exports',figsize=(15,5),lw=1)

# %%
df.plot.scatter(x='code',y='beef',figsize=(15,5))

# %%
df.plot.scatter(x='code',y='beef',c='total exports',s=df['corn'],figsize=(15,5),cmap='coolwarm')

# %%
df5 = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df5.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')

# %%
df['beef'].plot.kde()

# %% [markdown]
# # Great Job!
