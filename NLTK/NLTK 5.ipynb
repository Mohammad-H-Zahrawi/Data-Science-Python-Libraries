# %% [markdown]
# ## Analyzing Sentence Structure

# %% [markdown]
# ## general parsing

# %%
import nltk

# %%
# nltk.parse_cfg
groucho_grammer  = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
                                  """)

# %%
sent = ['I','shot','an','elephant','in','my','pajamas']
parser = nltk.ChartParser(groucho_grammer)
trees = parser.parse(sent)
for tree in trees :
    print (tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %%
nltk.app.rdparser()

# %%
## Fighting animals could be dangerous.
## Visiting relatives can be tiresome.

# %%
# nltk.parse_cfg
grammer1  = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I' | V N
VP -> V NP | VP PP | V V JJ
N -> JJ N
S -> Aux NP VP
Det -> 'an' | 'my'
N ->  'animals' | 'relatives'
V -> 'could' | 'be' | 'fighting' | 'visiting' | 'can'
P -> 'in'
JJ -> 'dangerous' | 'tiresome'

                                  """)

# %%
sent1 = ['fighting','animals','could','be','dangerous']
sent2 = ['visiting','relatives','can','be','tiresome']

# %%
parser = nltk.ChartParser(grammer1)

# %%
trees = parser.parse(sent2)
for tree in trees :
    print (tree)
# Out:
# (S (NP (V visiting) (N relatives)) (VP (V can) (V be) (JJ tiresome)))

# %% [markdown]
# ## Context-Free Grammar

# %%
grammar1 = nltk.CFG.fromstring("""
S -> NP VP
VP -> V NP | V NP PP
PP -> P NP
V -> "saw" | "ate" | "walked"
NP -> "John" | "Mary" | "Bob" | Det N | Det N PP
Det -> "a" | "an" | "the" | "my"
N -> "man" | "dog" | "cat" | "telescope" | "park"
P -> "in" | "on" | "by" | "with"
""")
sent = "Mary saw Bob".split()
rd_parser = nltk.RecursiveDescentParser(grammar1)

# %%
for tree in rd_parser.parse(sent):
    print (tree)
# Out:
# (S (NP Mary) (VP (V saw) (NP Bob)))

# %% [markdown]
# ## Recursion in Syntactic Structure

# %%
grammar2 = nltk.CFG.fromstring("""
S -> NP VP
NP -> Det Nom | PropN
Nom -> Adj Nom | N
VP -> V Adj | V NP | V S | V NP PP
PP -> P NP
PropN -> 'Buster' | 'Chatterer' | 'Joe'
Det -> 'the' | 'a'
N -> 'bear' | 'squirrel' | 'tree' | 'fish' | 'log'
Adj -> 'angry' | 'frightened' | 'little' | 'tall'
V -> 'chased'| 'saw' | 'said' | 'thought' | 'was' | 'put'
P -> 'on'
""")

# %%
rd_parser = nltk.RecursiveDescentParser(grammar1)
sent = 'Mary saw a dog'.split()

# %%
for tree in rd_parser.parse(sent):
    print (tree)
# Out:
# (S (NP Mary) (VP (V saw) (NP (Det a) (N dog))))

# %% [markdown]
# ## Shift-Reduce Parsing

# %%
nltk.app.srparser()
# Out:
# Warning: VP -> V NP PP will never be used

# %%
sr_parse = nltk.ShiftReduceParser(grammar1,trace=2)
sent = 'Mary saw a dog'.split()
s=(sr_parse.parse(sent))
print(*s)
# Out:
# Parsing 'Mary saw a dog'
#     [ * Mary saw a dog]
#   S [ 'Mary' * saw a dog]
#   R [ NP * saw a dog]
#   S [ NP 'saw' * a dog]
#   R [ NP V * a dog]
#   S [ NP V 'a' * dog]
#   R [ NP V Det * dog]
#   S [ NP V Det 'dog' * ]
#   R [ NP V Det N * ]
#   R [ NP V NP * ]
#   R [ NP VP * ]
#   R [ S * ]
# (S (NP Mary) (VP (V saw) (NP (Det a) (N dog))))

# %%
# interactive chart parser
nltk.app.chartparser()
# Out:
# grammar= (
# ('    ', 'S -> NP VP,')
# ('    ', 'VP -> VP PP,')
# ('    ', 'VP -> V NP,')
# ('    ', 'VP -> V,')
# ('    ', 'NP -> Det N,')
# ('    ', 'NP -> NP PP,')
# ('    ', 'PP -> P NP,')
# ('    ', "NP -> 'John',")
# ('    ', "NP -> 'I',")
# ('    ', "Det -> 'the',")
# ('    ', "Det -> 'my',")
# ('    ', "Det -> 'a',")
# ('    ', "N -> 'dog',")
# ('    ', "N -> 'cookie',")
# ('    ', "N -> 'table',")
# ('    ', "N -> 'cake',")
# ('    ', "N -> 'fork',")
# ('    ', "V -> 'ate',")
# ('    ', "V -> 'saw',")
# ('    ', "P -> 'on',")
# ('    ', "P -> 'under',")
# ('    ', "P -> 'with',")
# )
# tokens = ['John', 'ate', 'the', 'cake', 'on', 'the', 'table']
# Calling "ChartParserApp(grammar, tokens)"...

# %% [markdown]
# ## Treebanks and Grammars

# %%
from nltk.corpus import treebank

# %%
t=treebank.parsed_sents('wsj_0001.mrg')[0]
print(t)
# Out:
# (S
#   (NP-SBJ
#     (NP (NNP Pierre) (NNP Vinken))
#     (, ,)
#     (ADJP (NP (CD 61) (NNS years)) (JJ old))
#     (, ,))
#   (VP
#     (MD will)
#     (VP
#       (VB join)
#       (NP (DT the) (NN board))
#       (PP-CLR (IN as) (NP (DT a) (JJ nonexecutive) (NN director)))
#       (NP-TMP (NNP Nov.) (CD 29))))
#   (. .))

# %% [markdown]
# ## probability CFG

# %%
grammar = nltk.PCFG.fromstring("""
S -> NP VP [1.0]
VP -> TV NP [0.4]
VP -> IV [0.3]
VP -> DatV NP NP [0.3]
TV -> 'saw' [1.0] 
IV -> 'ate' [1.0]
DatV -> 'gave' [1.0]
NP -> 'telescopes' [0.8]
NP -> 'Jack' [0.2]
""")
print (grammar)
# Out:
# Grammar with 9 productions (start state = S)
#     S -> NP VP [1.0]
#     VP -> TV NP [0.4]
#     VP -> IV [0.3]
#     VP -> DatV NP NP [0.3]
#     TV -> 'saw' [1.0]
#     IV -> 'ate' [1.0]
#     DatV -> 'gave' [1.0]
#     NP -> 'telescopes' [0.8]
#     NP -> 'Jack' [0.2]

# %%
viterbi_parser = nltk.ViterbiParser(grammar)

# %%
print(*viterbi_parser.parse(['Jack', 'saw','telescopes']))
# Out:
# (S (NP Jack) (VP (TV saw) (NP telescopes))) (p=0.064)

# %%
grammar22 = nltk.CFG.fromstring("""
S -> NP VP | Aux NP VP | VP
NP -> Det Nom | PropN | PRON
Nom -> Adj Nom | N | Nom PP | Nom PP
VP -> V Adj | V NP | V S | V NP PP | V | VP PP
PP -> P NP
PropN -> 'Buster' | 'Chatterer' | 'Joe'
PRON -> 'he' | 'she'
Det -> 'the' | 'a' | 'this'
N -> 'bear' | 'squirrel' | 'tree' | 'fish' | 'log' | 'book' | 'boys' | 'girl'
PRP -> 'with' | 'in'
Adj -> 'angry' | 'frightened' | 'little' | 'tall'
V -> 'chased'| 'saw' | 'said' | 'thought' | 'was' | 'put' | 'takes' | 'take'
P -> 'on'
""")

# %%
sent = "take this book".split()
rd_parser = nltk.RecursiveDescentParser(grammar22)

# %%
for tree in rd_parser.parse(sent):
    print(tree)
# Out:
# (S (VP (V take) (NP (Det this) (Nom (N book)))))
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-32-a233bdf16e08> in <module>
# ----> 1 for tree in rd_parser.parse(sent):
#       2     print(tree)
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     129         # If the next element on the frontier is a token, match it.
#     130         else:
# --> 131             for result in self._match(remaining_text, tree, frontier):
#     132                 yield result
#     133
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _match(self, rtext, tree, frontier)
#     168             if self._trace:
#     169                 self._trace_match(newtree, frontier[1:], rtext[0])
# --> 170             for result in self._parse(rtext[1:], newtree, frontier[1:]):
#     171                 yield result
#     172         else:
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     129         # If the next element on the frontier is a token, match it.
#     130         else:
# --> 131             for result in self._match(remaining_text, tree, frontier):
#     132                 yield result
#     133
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _match(self, rtext, tree, frontier)
#     168             if self._trace:
#     169                 self._trace_match(newtree, frontier[1:], rtext[0])
# --> 170             for result in self._parse(rtext[1:], newtree, frontier[1:]):
#     171                 yield result
#     172         else:
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
# ...
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     227                     self._trace_expand(newtree, new_frontier, production)
#     228                 for result in self._parse(
# --> 229                     remaining_text, newtree, new_frontier + frontier[1:]
#     230                 ):
#     231                     yield result
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     129         # If the next element on the frontier is a token, match it.
#     130         else:
# --> 131             for result in self._match(remaining_text, tree, frontier):
#     132                 yield result
#     133
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _match(self, rtext, tree, frontier)
#     168             if self._trace:
#     169                 self._trace_match(newtree, frontier[1:], rtext[0])
# --> 170             for result in self._parse(rtext[1:], newtree, frontier[1:]):
#     171                 yield result
#     172         else:
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             for result in self._expand(remaining_text, tree, frontier):
#     127                 yield result
#     128
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     219                     newtree = subtree
#     220                 else:
# --> 221                     newtree = tree.copy(deep=True)
#     222                     newtree[frontier[0]] = subtree
#     223                 new_frontier = [
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\tree.py in copy(self, deep)
#     565             return type(self)(self._label, self)
#     566         else:
# --> 567             return type(self).convert(self)
#     568
#     569     def _frozen_class(self):
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\tree.py in convert(cls, tree)
#     550         """
#     551         if isinstance(tree, Tree):
# --> 552             children = [cls.convert(child) for child in tree]
#     553             return cls(tree._label, children)
#     554         else:
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\tree.py in <listcomp>(.0)
#     550         """
#     551         if isinstance(tree, Tree):
# --> 552             children = [cls.convert(child) for child in tree]
#     553             return cls(tree._label, children)
#     554         else:
#
# ... last 2 frames repeated, from the frame below ...
#
# D:\SOFTWARES DATA SCIENCE\Anaconda\lib\site-packages\nltk\tree.py in convert(cls, tree)
#     550         """
#     551         if isinstance(tree, Tree):
# --> 552             children = [cls.convert(child) for child in tree]
#     553             return cls(tree._label, children)
#     554         else:
#
# RecursionError: maximum recursion depth exceeded
