# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammad-H-Zahrawi/Data-Science-Python-Libraries/blob/master/python%2Bnumpy%2Bpandas%2Bmatplotlib/4_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Basic matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x=np.linspace(0,10,20)
y=x**2

# %%
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
y
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
plt.plot(x,y,'b','go',linewidth=4)
plt.xlabel('width')
plt.ylabel('height')
plt.title('title')
plt.show()

# %% [markdown]
# ## matplotlib object oriented method

# %%
plt.subplot(1,3,1)
plt.plot(x,y,'r--')
plt.subplot(1,3,2)
plt.plot(y,x,'b')
plt.subplot(1,3,3)
plt.plot(x,x,'g')
plt.title('third shape')
# Out:
# Text(0.5, 1.0, 'third shape')

# %%
# Create Figure (empty canvas)
fig = plt.figure()

# Add set of axes to figure
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

# Plot on that set of axes
axes.plot(x, y, 'b')
axes.set_xlabel('Set X Label') # Notice the use of set_ to begin methods
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %% [markdown]
# ## subplots()

# %%
fig , axes = plt.subplots()
axes.plot(x,y,'g')
axes.set_xlabel('X-axis')
axes.set_ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
fig,axes=plt.subplots(1,2)
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7a06cf1c50>,
# ...
#       dtype=object)

# %%
for ax in axes:
    ax.plot(x, y, 'b')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

# Display the figure object    
plt.tight_layout()
fig

# %%
fig,axes=plt.subplots(1,2,figsize=(12,4),dpi=80)
axes[0].plot(x,y,'g--',linewidth=4,)
axes[1].plot(y,x,'ro')
plt.tight_layout()

# %%
fig,axes=plt.subplots(3,3)
plt.tight_layout()

# %% [markdown]
# ## saving figures

# %%
fig.savefig('myfigure.jpg')

# %%
fig.savefig('myfigure.jpg',dpi=200)

# %% [markdown]
# ## legends

# %%
fig = plt.figure()
ax= fig.add_axes([0.1,0.1,1,1])
ax.plot(x,x**2,label='x squared')
ax.plot(x,x**3,label='x cubed')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
#legend
ax.legend(loc=0)

# %% [markdown]
# ## Setting colors, linewidths, linetypes

# %%
fig,ax=plt.subplots(figsize=(8,6))
ax.plot(x,y,color='red',linewidth=3,linestyle='--',marker='o',markersize=10,markerfacecolor='blue',markeredgewidth=3,
        markeredgecolor="black")

# %%
fig,ax=plt.subplots(figsize=(8,6))
ax.plot(x,y,color='g',lw=3,linestyle=':',marker='s')

# %% [markdown]
# ## Plot range

# %%
fig,axis=plt.subplots(1,3,figsize=(12,4))
axis[0].plot(x,y,'ro')
axis[0].set_title("default axes ranges")

axis[1].plot(x,x**2,'g-')
axis[1].set_title('tight axes')
axis[1].axis('tight')

axis[2].plot(x,x**3)
axis[2].set_title('custome axes range')
axis[2].set_ylim([0,60])
axis[2].set_xlim([2,5])
# Out:
# (2.0, 5.0)

# %% [markdown]
# # Special Plot Types

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([10.,  9.,  8., 10.,  7., 11.,  9., 13., 12., 11.]),
#  array([  5. , 101.6, 198.2, 294.8, 391.4, 488. , 584.6, 681.2, 777.8,
#         874.4, 971. ]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %% [markdown]
# # others

# %%
# to change the style
plt.style.use('fivethirtyeight')

# %%
# to show your figure
plt.show()

# %%
# %matplotlib notebook
#interactive plots embedded within the notebook
# %matplotlib inline
#images of your plot embedded in the notebook

# %%
fig,ax=plt.subplots(figsize=(4,4))
ax.plot(x,y)
ax.axis([0,15,-10,20])
# ax.axis([x-min , x-max , y-min , y-max])
# Out:
# (0.0, 15.0, -10.0, 20.0)

# %%
#scatter
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.plot(x, y, '-ok', color='black',label='sin')
plt.ylim(-1.5,1.5)
plt.legend(loc=2,frameon=True,shadow=True,framealpha=True)

# %%
plt.scatter(x,y,marker='o',color='black')

# %%
import numpy as np
rng=np.random.RandomState(0)
x=rng.randn(100)
y=rng.randn(100)
colors=rng.rand(100)
sizes=1000*rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,cmap='viridis')
plt.colorbar();

# %% [markdown]
# ## error bar

# %%
plt.style.use('seaborn-white')
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='o',color='blue',ecolor='lightgreen');

# %% [markdown]
# ## contour plots

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
Y
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.12820513, 0.12820513, 0.12820513, ..., 0.12820513, 0.12820513,
#         0.12820513],
#        [0.25641026, 0.25641026, 0.25641026, ..., 0.25641026, 0.25641026,
#         0.25641026],
#        ...,
#        [4.74358974, 4.74358974, 4.74358974, ..., 4.74358974, 4.74358974,
#         4.74358974],
#        [4.87179487, 4.87179487, 4.87179487, ..., 4.87179487, 4.87179487,
#         4.87179487],
#        [5.        , 5.        , 5.        , ..., 5.        , 5.        ,
#         5.        ]])

# %%
plt.contour(X, Y, Z, colors='black');

# %%
In[4]: plt.contour(X, Y, Z,20,cmap='RdGy');

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar()

# %%
contours=plt.contour(X,Y,Z,3,colors='black')
plt.clabel(contours,inline=True,fontsize=8)
plt.imshow(Z,extent=[0,5,0,5],origin='lower',cmap='RdGy',alpha=0.6)
plt.colorbar()

# %% [markdown]
# ## Histograms

# %%
data = np.random.randn(1000)
plt.hist(data,bins=20,density=True,alpha=0.5,color='blue',edgecolor='red');

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
plt.hist(x1,histtype='stepfilled', alpha=0.3, density=True, bins=40,color='blue')
plt.hist(x2,histtype='stepfilled', alpha=0.3, density=True, bins=40,color='red')
plt.hist(x3, histtype='stepfilled', alpha=0.3, density=True, bins=40,color='yellow');

# %%
counts, bin_edges = np.histogram(data, bins=5)
print(counts)
# Out:
# [ 54 244 449 212  41]

# %%
x=np.random.randint(1,50,500)
y=np.random.randint(1,50,500)

# %%
plt.hist2d(x,y,20,cmap='Blues')
cb = plt.colorbar(cmap='gray')
cb.set_label('counts in bin');

# %%
plt.hexbin(x, y, gridsize=20, cmap='Blues')
plt.colorbar(label='count in bin')

# %% [markdown]
# ## Customizing Plot Legends

# %%
x=np.linspace(1,10,1000)
plt.plot(x,np.sin(x),linewidth=2,color='red',label='sin')
plt.plot(x,np.cos(x),linewidth=2,color='blue',label='cos')
plt.legend(frameon=True,framealpha=1 );

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x - 0 * np.pi / 2),'-', color='black',label='line A')
ax.plot(x, np.sin(x - 1 * np.pi / 2),'--' ,color='black',label='line B')
ax.plot(x, np.sin(x - 2 * np.pi / 2),'-.' ,color='black',label='line C')
ax.plot(x, np.sin(x - 3 * np.pi / 2), ':',color='black',label='line D')
ax.axis('equal')
ax.legend(['line A', 'line B','line C','line D'],loc='upper right', frameon=False)

# %% [markdown]
# ## color bar

# %%
plt.style.use('classic')
x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])
plt.imshow(I)
plt.colorbar();

# %%
plt.imshow(I, cmap='gray');

# %% [markdown]
# ## subplots

# %%
fig,ax=plt.subplots(2,3,sharex='col',sharey='row')

# %%
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)
plt.subplot(grid[0, 0])
plt.subplot(grid[0, 1:])
plt.subplot(grid[1, :2])
plt.subplot(grid[1, 2]);

# %% [markdown]
# ## text

# %%
fig, ax = plt.subplots(facecolor='lightgray')
ax.axis([0, 10, 0, 10])
ax.text(1, 5, ". Data: (1, 5)", transform=ax.transData)
ax.text(0.5, 0.1, ". Axes: (5, 1)", transform=ax.transAxes)
ax.text(0.2, 0.2, ". Figure: (1, 1)", transform=fig.transFigure);

# %%
ax.set_xlim(0, 2)
ax.set_ylim(-6, 6)
fig

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')
ax.annotate('local maximum', xy=(6.28, 1), xytext=(10, 4),arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(10, 4, 'local maximum')

# %% [markdown]
# ## style sheets

# %%
def hist_and_lines():
    np.random.seed(0)
    fig, ax = plt.subplots(1, 2, figsize=(11, 4))
    ax[0].hist(np.random.randn(1000))
    for i in range(3):
        ax[1].plot(np.random.rand(10))
        ax[1].legend(['a', 'b', 'c'], loc='lower left')

# %%
hist_and_lines()

# %%
with plt.style.context('fivethirtyeight'):
    hist_and_lines()

# %%
with plt.style.context('ggplot'):
    hist_and_lines()

# %%
with plt.style.context('bmh'):
    hist_and_lines()

# %% [markdown]
# ## Changing the Defaults: rcParams

# %%
IPython_default = plt.rcParams.copy()
from matplotlib import cycler
colors = cycler('color',['#EE6666', '#3388BB', '#9988DD','#EECC55', '#88BB44', '#FFBBBB'])
plt.rc('axes', facecolor='#E6E6E6', edgecolor='none',axisbelow=True, grid=True, prop_cycle=colors)
plt.rc('grid', color='w', linestyle='solid')
plt.rc('xtick', direction='out', color='gray')
plt.rc('ytick', direction='out', color='gray')
plt.rc('patch', edgecolor='#E6E6E6')
plt.rc('lines', linewidth=2)

# %% [markdown]
# ## Three-Dimensional Plotting in Matplotlib

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
ax = plt.axes(projection='3d')
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %% [markdown]
# # The End
